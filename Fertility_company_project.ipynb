# %% [markdown]
# # Import packages

# %%
# !pip install us
# !pip install timedelta
import us
import pickle
import pandas as pd
import plotly.express as px
from google.colab import drive
from datetime import datetime
import copy
import timedelta

drive.mount('/content/drive')
root_path = '<path to the root path'
# Out:
# Requirement already satisfied: us in /usr/local/lib/python3.10/dist-packages (3.1.1)
# Requirement already satisfied: jellyfish==0.11.2 in /usr/local/lib/python3.10/dist-packages (from us) (0.11.2)
# Requirement already satisfied: timedelta in /usr/local/lib/python3.10/dist-packages (2020.12.3)
# Mounted at /content/drive

# %% [markdown]
# # Time difference function

# %%
def time_difference(T1, T2):
  # Converting the dates to the datetime objects
  T1 = datetime.strptime(T1, '%m/%d/%Y')
  T2 = datetime.strptime(T2, '%m/%d/%Y')
  # Computing the delta time
  td = timedelta.Timedelta(T2 - T1)

  return td

# %% [markdown]
# # Loading the data

# %%
payments_df = pd.read_csv(f'{root_path}Payments.csv')
charges_df = pd.read_csv(f'{root_path}Charges.csv')
adjustments_df = pd.read_csv(f'{root_path}Adjustments.csv')
demographic_data_df = pd.read_csv(f'{root_path}Patient Demographic Data.csv')

# %% [markdown]
# # Top 10 popular procedures

# %% [markdown]
# Top 10 procedures that was performed the most.

# %%
# Get the number of the requests for each procedure
Procedures_count = charges_df['Name'].value_counts()

#Create a bar plot
fig = px.bar(x=Procedures_count.index[:10], y=Procedures_count.values[:10], title='Top 10 popular procedures', labels={'x': 'Procedure name', 'y': '#Requests'},  text_auto='.2s')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="64d29226-ed39-44fd-947d-0ca942a655c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("64d29226-ed39-44fd-947d-0ca942a655c4")) {                    Plotly.newPlot(                        "64d29226-ed39-44fd-947d-0ca942a655c4",                        [{"alignmentgroup":"True","hovertemplate":"Procedure name=%{x}\u003cbr\u003e#Requests=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2s}","x":["Estradiol","Office Visit Established Patient Level 4","Ultrasound Transvaginal","Storage Embryo Monthly Yrs 3-5","Storage Embryo Monthly Yrs 1-2","Storage Embryo Monthly Over 5 Years","Storage Egg Monthly","Office Visit Established Patient Level 1","Ultrasound Pelvic Limited","Progesterone"],"xaxis":"x","y":[15196,14059,11707,10873,10558,8105,7621,6429,5978,5921],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatter ...

# %% [markdown]
# #Top 10 most expensive procedures

# %% [markdown]
# In the case that we want to find the most expensive procedures, we have to take an average cost for each procedure.

# %%
# Computes the cost on average for each procedure to be done
Procedure_cost = charges_df[['Name', 'Amount']].groupby(by = 'Name').mean().reset_index().sort_values('Amount', ascending = False).head(10)

#Create a bar plot
fig = px.bar(x=Procedure_cost['Name'], y=Procedure_cost['Amount'], title='Top 10 most expensive procedures', labels={'x': 'Procedure name', 'y': 'Cost'},  text_auto='.2s')


# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b01e4433-719a-4c2e-96af-df4da0249496" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b01e4433-719a-4c2e-96af-df4da0249496")) {                    Plotly.newPlot(                        "b01e4433-719a-4c2e-96af-df4da0249496",                        [{"alignmentgroup":"True","hovertemplate":"Procedure name=%{x}\u003cbr\u003eCost=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2s}","x":["Ultrasound, pelvic (nonobstetric), real time with image documentation","Hysteroscopy W Removal Of Leiomyomata","Treatment Of Missed Abortion Compl Surg 1st Trim","Hysteroscopy Surgical W Biopsy Endometrium Polyp","Hysteroscopy W Division Or Resection Of Intrauterine","Complete IVF Cycle","IVF Case Rate","Multi-Cycle Global Program Complete","Donor Egg Cycle Incomp Case Rate Before Retrieval","Hysteroscopy Surgical W Lysis Of Intrauterine Adh"],"xaxis":"x","y":[16833.2,10264.135,8832.303,8405.982188449849,6709.441666666667,6415.0,6318.799999999999,6292.75,6200.0,4668.538095238096],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":"" ...

# %% [markdown]
# # Top 10 most credited procedures

# %% [markdown]
# We show the top 10 procedures that credited the highest total money

# %%
# Computes the cost on average for each procedure to be done
Procedure_credited = charges_df[['Name', 'Amount']].groupby(by = 'Name').sum().reset_index().sort_values('Amount', ascending = False).head(10)

#Create a bar plot
fig = px.bar(x=Procedure_credited['Name'], y=Procedure_credited['Amount'], title='Top 10 most credited procedures', labels={'x': 'Procedure name', 'y': 'Total credit'},  text_auto='.2s')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cdef3cbc-f6fd-4e45-a03d-4c78d48dc846" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cdef3cbc-f6fd-4e45-a03d-4c78d48dc846")) {                    Plotly.newPlot(                        "cdef3cbc-f6fd-4e45-a03d-4c78d48dc846",                        [{"alignmentgroup":"True","hovertemplate":"Procedure name=%{x}\u003cbr\u003eTotal credit=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2s}","x":["Egg Retrieval","Hysteroscopy Surgical W Biopsy Endometrium Polyp","PGD or PGS Biopsy LTE 5 Embryos","Embryology Freeze All","Frozen Embryo Transfer","Storage Embryo Monthly Over 5 Years","Retrieval","IVF Frozen Embryo Cycle","Retrieval Facility","Early Monitoring"],"xaxis":"x","y":[4798329.49,2765568.14,2563500.0,1905100.0,1549538.0,1025713.81,1020750.0,1003710.0,935730.0,928610.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpola ...

# %% [markdown]
# # Doctor's most performed procedures

# %%
# This dictionary contains the info for each doctor
Doctors_procedures = []

for doctor_id in charges_df['Doctor'].unique():

  # filtering the records for each specific doctor
  filtered_rec = charges_df[charges_df['Doctor']== doctor_id]

  # Procedures distribution
  Procedure_dist = filtered_rec['Name'].value_counts()

  Doctors_procedures.append({'Doctor': doctor_id,
                             'Most procedure performed ' : Procedure_dist.index[0],
                             'Total count' : Procedure_dist.values[0]})

# Forming the dataframe for the doctors to represent which procedure they performed the most
pd.DataFrame(Doctors_procedures).sort_values('Total count', ascending = False)
# Out:
#     Doctor                 Most procedure performed   Total count
# 0        5                                 Estradiol         4224
# 4        9  Office Visit Established Patient Level 4         3649
# 5        6                       Storage Egg Monthly         3077
# 1        3  Office Visit Established Patient Level 4         1935
# 6        0            Storage Embryo Monthly Yrs 1-2         1729
# 10       1  Office Visit Established Patient Level 4         1525
# 2        8            Storage Embryo Monthly Yrs 3-5         1415
# 3        7  Office Visit Established Patient Level 4          843
# 9        2            Storage Embryo Monthly Yrs 1-2          807
# 7        4            Storage Embryo Monthly Yrs 3-5          269
# 8       10              Semen Analysis Comprehensive           24

# %% [markdown]
# # Doctor's Amount credited

# %%
# Computes the cost on average for each procedure to be done
Doctors_amount_credited = charges_df[['Doctor', 'Amount']].groupby(by = 'Doctor').sum().reset_index().sort_values('Amount', ascending = False)

#Create a bar plot
fig = px.bar(x=Doctors_amount_credited['Doctor'].astype(str), y=Doctors_amount_credited['Amount'], title='Doctors` amount credited', labels={'x': 'Doctor', 'y': 'Total credit'},  text_auto='.2s')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9f25c959-09a5-4af2-9ff9-a68d412c876d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9f25c959-09a5-4af2-9ff9-a68d412c876d")) {                    Plotly.newPlot(                        "9f25c959-09a5-4af2-9ff9-a68d412c876d",                        [{"alignmentgroup":"True","hovertemplate":"Doctor=%{x}\u003cbr\u003eTotal credit=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2s}","x":["5","9","6","3","0","8","1","7","2","4","10"],"xaxis":"x","y":[9195326.88,5809286.44,4413143.36,4138059.86,2621673.13,2501345.81,2277034.69,2200450.04,1766848.61,214538.89,-57.86999999999989],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5}, ...

# %%
Doctors_amount_credited
# Out:
#     Doctor      Amount
# 5        5  9195326.88
# 9        9  5809286.44
# 6        6  4413143.36
# 3        3  4138059.86
# 0        0  2621673.13
# 8        8  2501345.81
# 1        1  2277034.69
# 7        7  2200450.04
# 2        2  1766848.61
# 4        4   214538.89
# 10      10      -57.87

# %% [markdown]
# # Doctor's different procedures

# %% [markdown]
# In this plot, we are going to show how many different procedures each doctor can perform.

# %%
# This dictionary contains the info for each doctor
Doctors_procedures_distinct = []

for doctor_id in charges_df['Doctor'].unique():

  # filtering the records for each specific doctor
  filtered_rec = charges_df[charges_df['Doctor']== doctor_id]

  Doctors_procedures_distinct.append({'Doctor': doctor_id,
                                      'Procedures num' : len(filtered_rec['Name'].unique())})

# Forming the dataframe for the doctors to represent how many different procedures they can perform
Doctors_procedures_df = pd.DataFrame(Doctors_procedures_distinct).sort_values('Procedures num', ascending = False)

#Create a bar plot
fig = px.bar(x=Doctors_procedures_df['Doctor'].astype(str), y=Doctors_procedures_df['Procedures num'], title='Doctors` procedures performed', labels={'x': 'Doctor', 'y': '#Procedures capable of'},  text_auto='.3s')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3aa50b93-8ce9-492c-8dd4-783afa34e037" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3aa50b93-8ce9-492c-8dd4-783afa34e037")) {                    Plotly.newPlot(                        "3aa50b93-8ce9-492c-8dd4-783afa34e037",                        [{"alignmentgroup":"True","hovertemplate":"Doctor=%{x}\u003cbr\u003e#Procedures capable of=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.3s}","x":["5","9","6","3","8","1","7","0","4","2","10"],"xaxis":"x","y":[122,119,116,109,109,101,94,67,57,56,24],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scat ...

# %% [markdown]
# # Demographic insights

# %% [markdown]
# ## Top 5 states

# %% [markdown]
# We are going to identify the top 5 states that most of the patients are coming from.

# %%
# There were some null values in the column
# represented by 0 -> exclude them from the analysis
States_withoutNull = demographic_data_df[demographic_data_df['State'] != '0']

# Get the number of the patients from each state
State_counts = States_withoutNull['State'].value_counts()

#Create a bar plot
fig = px.bar(x=State_counts.index[:5], y=State_counts.values[:5], title='Top 5 states - #Patients', labels={'x': 'State', 'y': '#Patients'},  text_auto='.2s')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8f935ea8-8dc6-46be-84d9-42b2da2a519a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f935ea8-8dc6-46be-84d9-42b2da2a519a")) {                    Plotly.newPlot(                        "8f935ea8-8dc6-46be-84d9-42b2da2a519a",                        [{"alignmentgroup":"True","hovertemplate":"State=%{x}\u003cbr\u003e#Patients=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2s}","x":["CA","AZ","TX","FL","NY"],"xaxis":"x","y":[26863,164,162,91,78],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{" ...

# %% [markdown]
# # Top 10 international countries

# %% [markdown]
# In this section we are going to identify the top 10 countries that had the highest number of patients

# %%
# Getting the name of the states
state_names = [state.abbr for state in us.states.STATES_AND_TERRITORIES]

# Only keep the records that their state is not in the US
International = States_withoutNull[~(States_withoutNull['State'].isin(state_names))]

# Get the number of the patients from each state
International_count = International['State'].value_counts()

#Create a bar plot
fig = px.bar(x=International_count.index[:10], y=International_count.values[:10], title='Top 10 foreign countries - #Patients', labels={'x': 'Country name', 'y': '#Patients'},  text_auto='.2s')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="590c9c42-c25f-40c9-9268-1bcb39b50be1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("590c9c42-c25f-40c9-9268-1bcb39b50be1")) {                    Plotly.newPlot(                        "590c9c42-c25f-40c9-9268-1bcb39b50be1",                        [{"alignmentgroup":"True","hovertemplate":"Country name=%{x}\u003cbr\u003e#Patients=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2s}","x":["FC","DC","AP","MX","AE","UK","CH","CN","China","Beijing"],"xaxis":"x","y":[57,22,14,10,7,5,4,4,3,3],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[ ...

# %%
# MX - Mexico
# AE - United Arab Emirates

# %% [markdown]
# # In debt insights

# %% [markdown]
# Sort the data based on the encounter date

# %%
# drop the records from the charges that they have the encounter
# as null value
Charges_df_copy = charges_df.copy().dropna(subset = 'Encounter')

# Add a new column for the unix time of the encounter date
Charges_df_copy['Unix_encounter'] = Charges_df_copy.apply(lambda x: datetime.strptime(str(x['Encounter']), '%m/%d/%Y').timestamp(), axis = 1)

# Sorting the charges' records based on the unix timestamp
Charges_df_copy.sort_values(by = 'Unix_encounter', inplace = True)

Charges_df_copy
# Out:
#         Unique Acct #      Posted   Encounter      Code  \
# 14952          100018   3/17/2022    1/1/2000     99211
# 137420         106033   8/22/2023    1/3/2018   S4027Y6
# 79424          120163  12/29/2022   1/15/2018     89255
# 79405          120163  12/29/2022   1/15/2018     89352
# 79402          120163  12/29/2022    5/9/2018     84144
# ...               ...         ...         ...       ...
# 174072         102205  12/31/2023  12/31/2023  99214-25
# 174074         103032  12/31/2023  12/31/2023     76830
# 174080         103228  12/31/2023  12/31/2023     99211
# 173671         104095  12/27/2023    1/5/2024     89346
# 168354         120898   12/5/2023   1/12/2024     S4020
#
#                                             Name  Doctor  Facility  \
# 14952   Office Visit Established Patient Level 1       5         2
# 137420       Storage Embryo Monthly Over 5 Years       5         2
# 79424             Preparation Of Embryo Transfer       5         2
# 79405           Thawing Of Cryopreserved Embryos       5         2
# 79402                               Progesterone       5         2
# ...                                          ...     ...       ...
# 174072  Office Visit Established Patient Level 4       3         2
# 174074                   Ultrasound Transvaginal       3         2
# 174080  Office Visit Established Patient Level 1       2         2
# 173671                        Storage Egg Yearly       5         2
# 168354                  Cx IVF Before Aspiration       6         2
#
#                  Department  Billed To   Amount  Unix_encounter
# 14952   Evaluation And Mgmt       Zero     0.00    9.466848e+08
# 137420         Cryo Storage    Patient  1500.00    1.514938e+09
# 79424            Embryology    Patient    20.00    1.515974e+09
# 79405            Embryology    Patient    25.00    1.515974e+09
# 79402         Endocrinology    Patient     1.22    1.525824e+09
# ...                     ...        ...      ...             ...
# 174072  Evaluation And Mgmt  Insurance   105.00    1.703981e+09
# 174074           Sonography  Insurance   185.00    1.703981e+09
# 174080  Evaluation And Mgmt       Zero     0.00    1.703981e+09
# 173671         Cryo Storage  Insurance  1200.00    1.704413e+09
# 168354        IVF Case Rate  Insurance  1160.00    1.705018e+09
#
# [174053 rows x 11 columns]

# %% [markdown]
# ## __Saving the customers` data__ (Warning!)

# %% [markdown]
# Run the cell below only if you want to update the .pickle file containing the customers` data.

# %%
'''
# Consider a dictionary for each customer
# For each customer we want to track the followings:
# 1- Balance
# 2- The code and the name of the last procedure
# 3- The doctor of the customer that did the last procedure
# 4- The time that the balance got negative - date
# 5- List of the period that the balance was negative and got positive

# Template for each customer
Info_template = {'Balance' : 0,
                 'Last_procedure_code' : None,
                 'Last_procedure_name' : None,
                 'Last_procedure_doctor' : None,
                 'Negative_balance_date': None,
                 'Negative_balance_periods' : []}

# Customers' info
# Each key -> customer id
# Each value -> info template
All_customers_info = {}

# Looping over the records
for record_index in range(Charges_df_copy.shape[0]):


  # Take the customer index
  customer_idx = Charges_df_copy.iloc[record_index]['Unique Acct #']

  # If the customer has not been seen up to now
  if All_customers_info.get(customer_idx) == None:

    # Put a template for that customer
    All_customers_info[customer_idx] = copy.deepcopy(Info_template)

  # Finding the records corresponding to this procedure
  # in the payments -> summing up those payments and updating the customer balance
  procedure_encounter = Charges_df_copy.iloc[record_index]['Encounter']
  procedure_code = Charges_df_copy.iloc[record_index]['Code']
  procedure_charge = Charges_df_copy.iloc[record_index]['Amount']
  procedure_date = Charges_df_copy.iloc[record_index]['Encounter']

  procedure_payments = payments_df[(payments_df['Unique Acct #'] == customer_idx) &
                                   (payments_df['Encounter'] == procedure_encounter) &
                                   (payments_df['Code'] == procedure_code)]

  # Update the balance of the customer
  All_customers_info[customer_idx]['Balance'] += procedure_payments['Amount'].sum()

  # in the adjustments -> summing up those adjustments and updating the customer balance
  procedure_adjustments = adjustments_df[(adjustments_df['Unique Acct #'] == customer_idx) &
                                   (adjustments_df['Encounter'] == procedure_encounter) &
                                   (adjustments_df['Code'] == procedure_code)]
  # Update the balance of the customer
  All_customers_info[customer_idx]['Balance'] += procedure_adjustments['Amount'].sum()

  # deduct the charge from the balance of the customer
  All_customers_info[customer_idx]['Balance'] -= procedure_charge

  # rounding to two decimal points
  All_customers_info[customer_idx]['Balance'] = round(All_customers_info[customer_idx]['Balance'], 2)

  # When the balance gets negative and this procedure made the balance to get negative
  # take into account this date and the other information about the user.
  if All_customers_info[customer_idx]['Balance'] < 0 and  All_customers_info[customer_idx]['Negative_balance_date'] == None:

    # at this point the balance got negative
    All_customers_info[customer_idx]['Negative_balance_date'] = procedure_date

    # Update the name of the last procedure
    All_customers_info[customer_idx]['Last_procedure_name'] = Charges_df_copy.iloc[record_index]['Name']

    # Update the code of the last procedure
    All_customers_info[customer_idx]['Last_procedure_code'] = Charges_df_copy.iloc[record_index]['Code']

    # Update the doctor of the last procedure
    All_customers_info[customer_idx]['Last_procedure_doctor'] = Charges_df_copy.iloc[record_index]['Doctor']

  # If the balance of the customer got positive and previously it was negative, store the days that has been passed in order to
  # have the balance again positive and store the corresponding results to the list of the negative periods
  # 1- The number of days that the balance remained negative
  # 2- The last procedure that made the balance to be negative
  # 3- The Doctor of the last procedure
  # 4- The name of the procedure
  elif (All_customers_info[customer_idx]['Balance'] >= 0) and (All_customers_info[customer_idx]['Negative_balance_date'] != None):

    # Check the days passed from the last negative balance up to this timestamp
    # and add it to the list of periods
    Negative_date = All_customers_info[customer_idx]['Negative_balance_date']

    # Get the date that the balance got negative
    T1 = datetime.strptime(Negative_date, '%m/%d/%Y')

    # Get the date of the procedure
    T2 = datetime.strptime(procedure_date, '%m/%d/%Y')

    # Check the number of the days in this period
    td = timedelta.Timedelta(T2 - T1)

    # If in the same day the balance gets negative and then positive again,
    # don't consider that
    if td.days != 0:

      # adding the period to the list
      All_customers_info[customer_idx]['Negative_balance_periods'].append((td.days, All_customers_info[customer_idx]['Last_procedure_name'],
                                                                            All_customers_info[customer_idx]['Last_procedure_code'],
                                                                           All_customers_info[customer_idx]['Last_procedure_doctor']))

    # Reset the values that we have been considered to do our analysis
    All_customers_info[customer_idx]['Negative_balance_date'] = None
    All_customers_info[customer_idx]['Last_procedure_name'] = None
    All_customers_info[customer_idx]['Last_procedure_code'] = None
    All_customers_info[customer_idx]['Last_procedure_doctor'] = None

# Open the file in binary mode
with open(f'{root_path}Customer_agg_data.pickle', 'wb') as file:

    # Serialize and write the variable to the file
    pickle.dump(All_customers_info, file)
'''
print('Not running the feature extraction step!!!')

# %% [markdown]
# ## __Loading the customers` data__ (Warning)

# %% [markdown]
# Run the cell below only if you want to load the data from the .pickle file which contains the customers` data.

# %%
## Open the file in binary mode
with open(f'{root_path}Customer_agg_data.pickle', 'rb') as file:

    # Deserialize and retrieve the variable from the file
    All_customers_info = pickle.load(file)

# %% [markdown]
# Taking a look at some of the records

# %%
# Forming dataframe from the customers aggregated data
Customers_agg_df = pd.DataFrame(All_customers_info).T

# Resetting the indexes in the dataframe
Customers_agg_df.reset_index(inplace = True)

# Renaming the columns name
Customers_agg_df.columns = ['Customer id'] + list(Customers_agg_df.columns)[1:]

# Saving the data about all of the customers
Customers_agg_df.to_csv(f'{root_path}All_customers.csv', index = False)

Customers_agg_df
# Out:
#       Customer id   Balance Last_procedure_code  \
# 0          100018       0.0                None
# 1          106033    1020.0                None
# 2          120163    -125.0             S4027Y6
# 3          101400  73530.54                None
# 4          106071  16318.57                None
# ...           ...       ...                 ...
# 5272       103593     -75.0              89343Q
# 5273       104166       0.0                None
# 5274       104232    -250.0               99205
# 5275       103935    -166.0               89320
# 5276       104023    -166.0               99000
#
#                                     Last_procedure_name Last_procedure_doctor  \
# 0                                                  None                  None
# 1                                                  None                  None
# 2                   Storage Embryo Monthly Over 5 Years                     5
# 3                                                  None                  None
# 4                                                  None                  None
# ...                                                 ...                   ...
# 5272                            Storage Sperm Quarterly                     0
# 5273                                               None                  None
# 5274  New Patient Office Or Other Outpatient Visit L...                     1
# 5275                       Semen Analysis Comprehensive                     5
# 5276                                  Specimen Handling                     5
#
#      Negative_balance_date Negative_balance_periods
# 0                     None                       []
# 1                     None                       []
# 2               12/22/2023                       []
# 3                     None                       []
# 4                     None                       []
# ...                    ...                      ...
# 5272            12/28/2023                       []
# 5273                  None                       []
# 5274            12/28/2023                       []
# 5275            12/28/2023                       []
# 5276            12/29/2023                       []
#
# [5277 rows x 7 columns]

# %% [markdown]
# Taking a look at the customers that had negative periods

# %%
# Calculate how many negative periods each customer had
Customers_agg_df['#Negative_periods'] = Customers_agg_df.apply(lambda x: len(x['Negative_balance_periods']), axis = 1)

# Filter out the customers data that they had negative periods
Customers_agg_df[Customers_agg_df['#Negative_periods'] != 0 ]
# Out:
#       Customer id   Balance Last_procedure_code  \
# 134        128098   -264.76               58970
# 152        128442    1537.0                None
# 170        100142  47866.01                None
# 225        124195  15413.95                None
# 357        121994   -1401.3               A4649
# ...           ...       ...                 ...
# 5001       103879      75.0                None
# 5097       123385   -7411.0               89251
# 5108       120968      39.9                None
# 5127       103930  -12706.0               89250
# 5152       103713 -31394.15               58970
#
#                 Last_procedure_name Last_procedure_doctor  \
# 134                   Egg Retrieval                     2
# 152                            None                  None
# 170                            None                  None
# 225                            None                  None
# 357   Surgical Supply Miscellaneous                     8
# ...                             ...                   ...
# 5001                           None                  None
# 5097     CoCulture Of Egg Or Embryo                     6
# 5108                           None                  None
# 5127       Culture Of Egg Or Embryo                     7
# 5152                  Egg Retrieval                     0
#
#      Negative_balance_date                           Negative_balance_periods  \
# 134              1/14/2022                 [(65, Extended Culture, 89272, 0)]
# 152                   None                      [(7, Progesterone, 84144, 0)]
# 170                   None  [(1, Estradiol, 82670, 5), (2, Office Visit Es...
# 225                   None  [(11, Estradiol, 82670, 3), (5, Egg Retrieval,...
# 357              6/28/2023  [(2, Storage Embryo Yearly, 89342, 5), (7, Ult...
# ...                    ...                                                ...
# 5001                  None         [(2, Ultrasound Pelvic Limited, 76857, 6)]
# 5097            11/27/2023  [(17, New Patient Office Or Other Outpatient V...
# 5108                  None  [(15, New Patient Office Or Other Outpatient V...
# 5127             12/6/2023           [(9, Ultrasound Transvaginal, 76830, 0)]
# 5152             12/7/2023                         [(8, Estradiol, 82670, 0)]
#
#       #Negative_periods
# 134                   1
# 152                   1
# 170                   3
# 225                   2
# 357                   3
# ...                 ...
# 5001                  1
# 5097                  1
# 5108                  1
# 5127                  1
# 5152                  1
#
# [98 rows x 8 columns]

# %% [markdown]
# Identifying the customers that they still have negative balance (still some pending payments.

# %%
# This function would return the number of days that
# the balance is still in pending
def Compute_pending_days(procedure_date, lastest_date):

  # If there is a data that the balance got negative
  if procedure_date:

    # compute the differece
    return time_difference(procedure_date, lastest_date).days

  #Otherwise, return none
  return None


# Identify the latest time based on the records
Latest_time = Charges_df_copy['Encounter'].values[-1]

# Check for how many days the customer is in pending
Customers_agg_df['Pending_time'] = Customers_agg_df.apply(lambda x: Compute_pending_days(x['Negative_balance_date'], Latest_time) , axis = 1)

Customers_agg_df
# Out:
#       Customer id   Balance Last_procedure_code  \
# 0          100018       0.0                None
# 1          106033    1020.0                None
# 2          120163    -125.0             S4027Y6
# 3          101400  73530.54                None
# 4          106071  16318.57                None
# ...           ...       ...                 ...
# 5272       103593     -75.0              89343Q
# 5273       104166       0.0                None
# 5274       104232    -250.0               99205
# 5275       103935    -166.0               89320
# 5276       104023    -166.0               99000
#
#                                     Last_procedure_name Last_procedure_doctor  \
# 0                                                  None                  None
# 1                                                  None                  None
# 2                   Storage Embryo Monthly Over 5 Years                     5
# 3                                                  None                  None
# 4                                                  None                  None
# ...                                                 ...                   ...
# 5272                            Storage Sperm Quarterly                     0
# 5273                                               None                  None
# 5274  New Patient Office Or Other Outpatient Visit L...                     1
# 5275                       Semen Analysis Comprehensive                     5
# 5276                                  Specimen Handling                     5
#
#      Negative_balance_date Negative_balance_periods  #Negative_periods  \
# 0                     None                       []                  0
# 1                     None                       []                  0
# 2               12/22/2023                       []                  0
# 3                     None                       []                  0
# 4                     None                       []                  0
# ...                    ...                      ...                ...
# 5272            12/28/2023                       []                  0
# 5273                  None                       []                  0
# 5274            12/28/2023                       []                  0
# 5275            12/28/2023                       []                  0
# 5276            12/29/2023                       []                  0
#
#       Pending_time
# 0              NaN
# 1              NaN
# 2             21.0
# 3              NaN
# 4              NaN
# ...            ...
# 5272          15.0
# 5273           NaN
# 5274          15.0
# 5275          15.0
# 5276          14.0
#
# [5277 rows x 9 columns]

# %% [markdown]
# Check the number of customers that they have still pending payments.

# %%
# Identifying the customers that are still in debt
In_debt_cust = Customers_agg_df[~Customers_agg_df['Pending_time'].isnull()]

In_debt_cust
# Out:
#       Customer id Balance Last_procedure_code  \
# 2          120163  -125.0             S4027Y6
# 8          121227  -313.0            S4027Y35
# 11         126674 -770.24                 FWD
# 43         119502  -125.0             S4027Y6
# 55         123461  -377.0            S4027Y35
# ...           ...     ...                 ...
# 5271       103822   -16.0               99000
# 5272       103593   -75.0              89343Q
# 5274       104232  -250.0               99205
# 5275       103935  -166.0               89320
# 5276       104023  -166.0               99000
#
#                                     Last_procedure_name Last_procedure_doctor  \
# 2                   Storage Embryo Monthly Over 5 Years                     5
# 8                        Storage Embryo Monthly Yrs 3-5                     3
# 11                                      Balance Forward                     0
# 43                  Storage Embryo Monthly Over 5 Years                     5
# 55                       Storage Embryo Monthly Yrs 3-5                     9
# ...                                                 ...                   ...
# 5271                                  Specimen Handling                     5
# 5272                            Storage Sperm Quarterly                     0
# 5274  New Patient Office Or Other Outpatient Visit L...                     1
# 5275                       Semen Analysis Comprehensive                     5
# 5276                                  Specimen Handling                     5
#
#      Negative_balance_date Negative_balance_periods  #Negative_periods  \
# 2               12/22/2023                       []                  0
# 8               10/28/2023                       []                  0
# 11              12/14/2019                       []                  0
# 43              12/20/2023                       []                  0
# 55                7/7/2023                       []                  0
# ...                    ...                      ...                ...
# 5271            12/27/2023                       []                  0
# 5272            12/28/2023                       []                  0
# 5274            12/28/2023                       []                  0
# 5275            12/28/2023                       []                  0
# 5276            12/29/2023                       []                  0
#
#       Pending_time
# 2             21.0
# 8             76.0
# 11          1490.0
# 43            23.0
# 55           189.0
# ...            ...
# 5271          16.0
# 5272          15.0
# 5274          15.0
# 5275          15.0
# 5276          14.0
#
# [647 rows x 9 columns]

# %% [markdown]
# ## Pending payments

# %% [markdown]
# Here is the statistics about the payments that are still pending.

# %%
# We are going to consider the customers that they have still some payments to be paid
# Debt statistics
debt_stat = {'#In debt customers' : In_debt_cust.shape[0],
             'In debt total' : In_debt_cust['Balance'].abs().sum(),
             'In debt avg' : In_debt_cust['Balance'].abs().mean(),
             'In debt max' : In_debt_cust['Balance'].abs().max(),
             'In debt min' : In_debt_cust['Balance'].abs().min(),
             'In debt days avg' : In_debt_cust['Pending_time'].mean(),
             'In debt days max' : In_debt_cust['Pending_time'].max(),
             'In debt days min' : In_debt_cust['Pending_time'].min()}

pd.DataFrame([debt_stat])
# Out:
#    #In debt customers  In debt total  In debt avg  In debt max  In debt min  \
# 0                 647      898424.96  1388.601175     31394.15         0.29
#
#    In debt days avg  In debt days max  In debt days min
# 0         90.859351            1490.0              14.0

# %% [markdown]
# #Delinquent customers

# %% [markdown]
# Regarding identifying delinquent customers we will consider two different time periods, 30 and 60 days and give some insights about those different periods.

# %% [markdown]
# ### 30 days delinquent

# %% [markdown]
# First identifying the customers that they are in pending for more than 30 days

# %%
# customers that they are in pending for more than 30 days
delinquent_30_cust = In_debt_cust[In_debt_cust['Pending_time'] >= 30 ]

delinquent_30_cust
# Out:
#       Customer id  Balance Last_procedure_code  \
# 8          121227   -313.0            S4027Y35
# 11         126674  -770.24                 FWD
# 55         123461   -377.0            S4027Y35
# 86         123600    -63.0            S4027Y35
# 93         123764 -8294.25               76830
# ...           ...      ...                 ...
# 5216       123717   -42.44            99214-95
# 5219       104195   -885.0               99499
# 5225       104207  -1196.0               99000
# 5226       104198   -117.0            99205-95
# 5227       104191   -270.0               99205
#
#                                     Last_procedure_name Last_procedure_doctor  \
# 8                        Storage Embryo Monthly Yrs 3-5                     3
# 11                                      Balance Forward                     0
# 55                       Storage Embryo Monthly Yrs 3-5                     9
# 86                       Storage Embryo Monthly Yrs 3-5                     6
# 93                              Ultrasound Transvaginal                     3
# ...                                                 ...                   ...
# 5216           Office Visit Established Patient Level 4                     9
# 5219         Unlisted Evaluation And Management Service                     1
# 5225                                  Specimen Handling                     9
# 5226  New Patient Office Or Other Outpatient Visit L...                     1
# 5227  New Patient Office Or Other Outpatient Visit L...                     9
#
#      Negative_balance_date Negative_balance_periods  #Negative_periods  \
# 8               10/28/2023                       []                  0
# 11              12/14/2019                       []                  0
# 55                7/7/2023                       []                  0
# 86               12/8/2023                       []                  0
# 93               12/3/2023                       []                  0
# ...                    ...                      ...                ...
# 5216            12/12/2023                       []                  0
# 5219            12/12/2023                       []                  0
# 5225            12/13/2023                       []                  0
# 5226            12/13/2023                       []                  0
# 5227            12/13/2023                       []                  0
#
#       Pending_time
# 8             76.0
# 11          1490.0
# 55           189.0
# 86            35.0
# 93            40.0
# ...            ...
# 5216          31.0
# 5219          31.0
# 5225          30.0
# 5226          30.0
# 5227          30.0
#
# [453 rows x 9 columns]

# %% [markdown]
# #### Statistics

# %% [markdown]
# Here we are giving some statistics about the customers that they are deliquent for 30 days

# %%
# Giving some statistics about delinquent customers for 30 days
delinquent_30_stat = {'#Delinquent customers' : delinquent_30_cust.shape[0],
             'Total amount' : delinquent_30_cust['Balance'].abs().sum(),
             'Amount per customer' : delinquent_30_cust['Balance'].abs().mean(),
             'Max amount' : delinquent_30_cust['Balance'].abs().max(),
             'Min amount' : delinquent_30_cust['Balance'].abs().min(),
             'Average delinquent days' : (delinquent_30_cust['Pending_time']-30).mean(),
             'Maximum delinquent days' : (delinquent_30_cust['Pending_time']-30).max(),
             'Minimum deliqneunt days' : (delinquent_30_cust['Pending_time']-30).min()}

pd.DataFrame([delinquent_30_stat])
# Out:
#    #Delinquent customers  Total amount  Amount per customer  Max amount  \
# 0                    453     858603.39          1895.371722    31394.15
#
#    Min amount  Average delinquent days  Maximum delinquent days  \
# 0        0.29                 91.11479                   1460.0
#
#    Minimum deliqneunt days
# 0                      0.0

# %% [markdown]
# #### Top 5 procedure

# %% [markdown]
# Here we are going to identify the procedure that made the balance to get negative

# %%
# Get the count of each procedure
procedure_count = delinquent_30_cust['Last_procedure_name'].value_counts()[:5]

#Create a bar plot
fig = px.bar(x=procedure_count.index, y=procedure_count.values, title='Top 5 last procedure deliquent customers for 30 days', labels={'x': 'Procedure', 'y': '#Cases'},  text_auto='.2s')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="23da6da1-9dbd-45f0-806a-78280dab05f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("23da6da1-9dbd-45f0-806a-78280dab05f1")) {                    Plotly.newPlot(                        "23da6da1-9dbd-45f0-806a-78280dab05f1",                        [{"alignmentgroup":"True","hovertemplate":"Procedure=%{x}\u003cbr\u003e#Cases=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2s}","x":["Storage Embryo Monthly Over 5 Years","New Patient Office Or Other Outpatient Visit Level 5","Storage Embryo Monthly Yrs 3-5","Storage Sperm Quarterly","Storage Egg Monthly"],"xaxis":"x","y":[84,56,53,30,23],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6", ...

# %% [markdown]
# #### Demographic insights

# %% [markdown]
# Check the demographic data of the customers that are deliqneunt for 30 days

# %%
# Get the id of the customers that are in debt
delinquent_30_cust_id = list(delinquent_30_cust['Customer id'].values)

# Filtering out the information of the people that are in debt
delinquent_30_demograph = demographic_data_df[demographic_data_df['Unique Acct #'].isin(delinquent_30_cust_id)]

delinquent_30_demograph
# Out:
#        Unique Acct #  Assigned Doctor State Sex at birth      Race  \
# 378           110337              5.0    CA            F   Not Set
# 697           110624              5.0    CA            F   Not Set
# 1046          101093              9.0    CA            F     Asian
# 1702          101152              2.0    CA            F     White
# 1768          101158              9.0    CA            F  Declined
# ...              ...              ...   ...          ...       ...
# 28344         109520              5.0    CA            F   Not Set
# 28704         109845              8.0    CA            F   Not Set
# 28713         109853              5.0    CA            F   Not Set
# 28738         109876              5.0    CA            M   Not Set
# 28852         100997              9.0    CA            F     White
#
#                     Ethnicity Marital Status   Patient Source   Age
# 378                   Not Set            NaN              NaN  50.0
# 697                   Not Set        Married              NaN  47.0
# 1046   Not Hispanic or Latino        Married           Friend  42.0
# 1702       Hispanic or Latino         Single           Doctor  30.0
# 1768                 Declined        Married           Doctor  40.0
# ...                       ...            ...              ...   ...
# 28344                 Not Set            NaN              NaN  50.0
# 28704                 Not Set            NaN              NaN  46.0
# 28713                 Not Set            NaN              NaN  54.0
# 28738                 Not Set            NaN              NaN  64.0
# 28852  Not Hispanic or Latino        Married  Healthcare Plan  30.0
#
# [453 rows x 9 columns]

# %% [markdown]
# #### Gender distribution

# %%
# Get the distribution of the delinquent for 30 days custmoers
delinquent_30_gender = delinquent_30_demograph['Sex at birth'].value_counts()

#Create a bar plot
fig = px.bar(x=delinquent_30_gender.index, y=delinquent_30_gender.values, title='Delinquent customers for 30 days - Gender distribution', labels={'x': 'Gender', 'y': '#Delinquent customers '},  text_auto='.2s')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a167842b-f384-4282-b0de-b7dddc581ad9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a167842b-f384-4282-b0de-b7dddc581ad9")) {                    Plotly.newPlot(                        "a167842b-f384-4282-b0de-b7dddc581ad9",                        [{"alignmentgroup":"True","hovertemplate":"Gender=%{x}\u003cbr\u003e#Delinquent customers =%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2s}","x":["F","M"],"xaxis":"x","y":[370,83],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0, ...

# %% [markdown]
# #### Doctors insight

# %% [markdown]
# Checking the doctor of the delinquent customers

# %%
# Check the count of the number of the delinquent customers
# for the doctors
delinquent_30_doctor = delinquent_30_demograph['Assigned Doctor'].astype('object').value_counts()

#Create a bar plot
fig = px.bar(x=list(map(str, delinquent_30_doctor.index)), y=delinquent_30_doctor.values, title='#Delinquent for 30 days customers of each doctors ', labels={'x': 'Doctor', 'y': '#Delinquent customers'},  text_auto='.2s')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="09df3804-33f2-498b-a478-b97e9406a73e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("09df3804-33f2-498b-a478-b97e9406a73e")) {                    Plotly.newPlot(                        "09df3804-33f2-498b-a478-b97e9406a73e",                        [{"alignmentgroup":"True","hovertemplate":"Doctor=%{x}\u003cbr\u003e#Delinquent customers=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2s}","x":["6.0","5.0","9.0","3.0","1.0","8.0","0.0","7.0","2.0"],"xaxis":"x","y":[92,86,80,56,51,40,22,16,10],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scatterg ...

# %% [markdown]
# #### Age insights

# %%
# Debt statistics
age_stat = {'In debt age avg' : delinquent_30_demograph['Age'].mean(),
            'In debt age max' : delinquent_30_demograph['Age'].max(),
            'In debt age min' : delinquent_30_demograph['Age'].min()}

pd.DataFrame([age_stat])
# Out:
#    In debt age avg  In debt age max  In debt age min
# 0        39.328918             67.0             16.0

# %% [markdown]
# #### Race insights

# %%
# Check the race distribution of the delinquent for 30 days customers
delinquent_30_race = delinquent_30_demograph['Race'].value_counts()

#Create a bar plot
fig = px.bar(x=delinquent_30_race.index, y=delinquent_30_race.values, title='Race distribution of deliquent for 30 days ', labels={'x': 'Race', 'y': '#Delinquent customers'},  text_auto='.2s')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="50404698-3314-4606-bdbf-f8980a95b1b9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("50404698-3314-4606-bdbf-f8980a95b1b9")) {                    Plotly.newPlot(                        "50404698-3314-4606-bdbf-f8980a95b1b9",                        [{"alignmentgroup":"True","hovertemplate":"Race=%{x}\u003cbr\u003e#Delinquent customers=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2s}","x":["Not Set","Declined","White","Asian","Other Race","Black or African American","Native Hawaiian or Other Pacific Islander"],"xaxis":"x","y":[146,127,107,47,13,12,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode" ...

# %%
# Check the ethnicity distribution of the delinquent for 30 days customers
delinquent_30_ethnicity = delinquent_30_demograph['Ethnicity'].value_counts()

#Create a bar plot
fig = px.bar(x=delinquent_30_ethnicity.index, y=delinquent_30_ethnicity.values, title='Ethnicity distribution of deliquent for 30 days ', labels={'x': 'ethnicity', 'y': '#Delinquent customers'},  text_auto='.2s')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bd224e41-5c64-4de3-8221-96313bf8bef2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd224e41-5c64-4de3-8221-96313bf8bef2")) {                    Plotly.newPlot(                        "bd224e41-5c64-4de3-8221-96313bf8bef2",                        [{"alignmentgroup":"True","hovertemplate":"ethnicity=%{x}\u003cbr\u003e#Delinquent customers=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2s}","x":["Not Hispanic or Latino","Not Set","Declined","Hispanic or Latino"],"xaxis":"x","y":[157,146,124,26],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scat ...

# %% [markdown]
# ### 60 days delinquent

# %% [markdown]
# First identifying the customers that they are in pending for more than 60 days

# %%
# customers that they are in pending for more than 60 days
delinquent_60_cust = In_debt_cust[In_debt_cust['Pending_time'] >= 60 ]

delinquent_60_cust
# Out:
#       Customer id Balance Last_procedure_code  \
# 8          121227  -313.0            S4027Y35
# 11         126674 -770.24                 FWD
# 55         123461  -377.0            S4027Y35
# 98         123758 -1030.0               89342
# 101        128261 -1470.0               76700
# ...           ...     ...                 ...
# 5040       103758  -302.0               58100
# 5052       123996  -152.7            99205-95
# 5055       103942  -885.0               99499
# 5069       103814  -110.0               99205
# 5081       103490 -9405.0               89353
#
#                                     Last_procedure_name Last_procedure_doctor  \
# 8                        Storage Embryo Monthly Yrs 3-5                     3
# 11                                      Balance Forward                     0
# 55                       Storage Embryo Monthly Yrs 3-5                     9
# 98                                Storage Embryo Yearly                     5
# 101   Ultrasound Abdominal B Scan And Or Real Time With                     0
# ...                                                 ...                   ...
# 5040                                 Endometrial Biopsy                     9
# 5052  New Patient Office Or Other Outpatient Visit L...                     8
# 5055         Unlisted Evaluation And Management Service                     1
# 5069  New Patient Office Or Other Outpatient Visit L...                     1
# 5081                                      Sperm Thawing                     1
#
#      Negative_balance_date Negative_balance_periods  #Negative_periods  \
# 8               10/28/2023                       []                  0
# 11              12/14/2019                       []                  0
# 55                7/7/2023                       []                  0
# 98                9/6/2023                       []                  0
# 101              10/6/2023                       []                  0
# ...                    ...                      ...                ...
# 5040            10/31/2023                       []                  0
# 5052             11/1/2023                       []                  0
# 5055             11/2/2023                       []                  0
# 5069             11/6/2023                       []                  0
# 5081             11/7/2023                       []                  0
#
#       Pending_time
# 8             76.0
# 11          1490.0
# 55           189.0
# 98           128.0
# 101           98.0
# ...            ...
# 5040          73.0
# 5052          72.0
# 5055          71.0
# 5069          67.0
# 5081          66.0
#
# [281 rows x 9 columns]

# %% [markdown]
# #### Statistics

# %% [markdown]
# Here we are giving some statistics about the customers that they are deliquent for 30 days

# %%
# Giving some statistics about delinquent customers for 60 days
delinquent_60_stat = {'#Delinquent customers' : delinquent_60_cust.shape[0],
             'Total amount' : delinquent_60_cust['Balance'].abs().sum(),
             'Amount per customer' : delinquent_60_cust['Balance'].abs().mean(),
             'Max amount' : delinquent_60_cust['Balance'].abs().max(),
             'Min amount' : delinquent_60_cust['Balance'].abs().min(),
             'Average delinquent days' : (delinquent_60_cust['Pending_time']-60).mean(),
             'Maximum delinquent days' : (delinquent_60_cust['Pending_time']-60).max(),
             'Minimum deliqneunt days' : (delinquent_60_cust['Pending_time']-60).min()}

pd.DataFrame([delinquent_60_stat])
# Out:
#    #Delinquent customers  Total amount  Amount per customer  Max amount  \
# 0                    281     483327.72          1720.027473     30262.1
#
#    Min amount  Average delinquent days  Maximum delinquent days  \
# 0        0.29               108.779359                   1430.0
#
#    Minimum deliqneunt days
# 0                      0.0

# %% [markdown]
# #### Top 5 procedure

# %% [markdown]
# Here we are going to identify the procedure that made the balance to get negative

# %%
# Get the count of each procedure
procedure_count = delinquent_60_cust['Last_procedure_name'].value_counts()[:5]

#Create a bar plot
fig = px.bar(x=procedure_count.index, y=procedure_count.values, title='Top 5 last procedure deliquent customers for 60 days', labels={'x': 'Procedure', 'y': '#Cases'},  text_auto='.2s')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0f39aac1-0208-4290-9996-e19379153b04" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0f39aac1-0208-4290-9996-e19379153b04")) {                    Plotly.newPlot(                        "0f39aac1-0208-4290-9996-e19379153b04",                        [{"alignmentgroup":"True","hovertemplate":"Procedure=%{x}\u003cbr\u003e#Cases=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2s}","x":["Storage Embryo Monthly Over 5 Years","New Patient Office Or Other Outpatient Visit Level 5","Storage Embryo Monthly Yrs 3-5","Storage Sperm Quarterly","Office Visit Established Patient Level 4"],"xaxis":"x","y":[46,39,31,15,13],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line ...

# %% [markdown]
# #### Demographic insights

# %% [markdown]
# Check the demographic data of the customers that are deliqneunt for 60 days

# %%
# Get the id of the customers that are in debt
delinquent_60_cust_id = list(delinquent_60_cust['Customer id'].values)

# Filtering out the information of the people that are in debt
delinquent_60_demograph = demographic_data_df[demographic_data_df['Unique Acct #'].isin(delinquent_60_cust_id)]

delinquent_60_demograph
# Out:
#        Unique Acct #  Assigned Doctor State Sex at birth  \
# 697           110624              5.0    CA            F
# 1046          101093              9.0    CA            F
# 1702          101152              2.0    CA            F
# 1924          101172              6.0    CA            F
# 2200          111978              5.0    CA            F
# ...              ...              ...   ...          ...
# 28058         109263              5.0    CA            F
# 28110         109309              5.0    CA            F
# 28142         100933              2.0    CA            F
# 28284         109467              5.0    CA            F
# 28344         109520              5.0    CA            F
#
#                             Race               Ethnicity Marital Status  \
# 697                      Not Set                 Not Set        Married
# 1046                       Asian  Not Hispanic or Latino        Married
# 1702                       White      Hispanic or Latino         Single
# 1924                       Asian  Not Hispanic or Latino        Married
# 2200   Black or African American  Not Hispanic or Latino        Married
# ...                          ...                     ...            ...
# 28058                    Not Set                 Not Set            NaN
# 28110                      White  Not Hispanic or Latino        Married
# 28142                      White      Hispanic or Latino         Single
# 28284                    Not Set                 Not Set            NaN
# 28344                    Not Set                 Not Set            NaN
#
#       Patient Source   Age
# 697              NaN  47.0
# 1046          Friend  42.0
# 1702          Doctor  30.0
# 1924          Doctor  42.0
# 2200   Family Member  42.0
# ...              ...   ...
# 28058            NaN  59.0
# 28110  Word of Mouth  64.0
# 28142            NaN  37.0
# 28284            NaN  49.0
# 28344            NaN  50.0
#
# [281 rows x 9 columns]

# %% [markdown]
# #### Gender distribution

# %%
# Get the distribution of the delinquent for 60 days custmoers
delinquent_60_gender = delinquent_60_demograph['Sex at birth'].value_counts()

#Create a bar plot
fig = px.bar(x=delinquent_60_gender.index, y=delinquent_60_gender.values, title='Delinquent customers for 60 days - Gender distribution', labels={'x': 'Gender', 'y': '#Delinquent customers '},  text_auto='.2s')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="75a1fd0a-8fc6-4e5f-ba0c-24982acd257c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75a1fd0a-8fc6-4e5f-ba0c-24982acd257c")) {                    Plotly.newPlot(                        "75a1fd0a-8fc6-4e5f-ba0c-24982acd257c",                        [{"alignmentgroup":"True","hovertemplate":"Gender=%{x}\u003cbr\u003e#Delinquent customers =%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2s}","x":["F","M"],"xaxis":"x","y":[233,48],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0, ...

# %% [markdown]
# #### Doctors insight

# %% [markdown]
# Checking the doctor of the delinquent customers

# %%
# Check the count of the number of the delinquent customers
# for the doctors
delinquent_60_doctor = delinquent_60_demograph['Assigned Doctor'].astype('object').value_counts()

#Create a bar plot
fig = px.bar(x=list(map(str, delinquent_60_doctor.index)), y=delinquent_60_doctor.values, title='#Delinquent for 60 days customers of each doctors ', labels={'x': 'Doctor', 'y': '#Delinquent customers'},  text_auto='.2s')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6cccc223-26a6-47be-a91d-47824f782144" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6cccc223-26a6-47be-a91d-47824f782144")) {                    Plotly.newPlot(                        "6cccc223-26a6-47be-a91d-47824f782144",                        [{"alignmentgroup":"True","hovertemplate":"Doctor=%{x}\u003cbr\u003e#Delinquent customers=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2s}","x":["6.0","9.0","5.0","3.0","1.0","8.0","0.0","2.0","7.0"],"xaxis":"x","y":[59,46,41,40,35,29,15,9,7],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo ...

# %% [markdown]
# #### Age insights

# %%
# Debt statistics
age_stat = {'In debt age avg' : delinquent_60_demograph['Age'].mean(),
            'In debt age max' : delinquent_60_demograph['Age'].max(),
            'In debt age min' : delinquent_60_demograph['Age'].min()}

pd.DataFrame([age_stat])
# Out:
#    In debt age avg  In debt age max  In debt age min
# 0        38.957295             65.0             19.0

# %% [markdown]
# #### Race insights

# %%
# Check the race distribution of the delinquent for 60 days customers
delinquent_60_race = delinquent_60_demograph['Race'].value_counts()

#Create a bar plot
fig = px.bar(x=delinquent_60_race.index, y=delinquent_60_race.values, title='Race distribution of deliquent for 60 days ', labels={'x': 'Race', 'y': '#Delinquent customers'},  text_auto='.2s')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="adeb25dc-c5fb-463f-8a2b-704f53ac59f4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("adeb25dc-c5fb-463f-8a2b-704f53ac59f4")) {                    Plotly.newPlot(                        "adeb25dc-c5fb-463f-8a2b-704f53ac59f4",                        [{"alignmentgroup":"True","hovertemplate":"Race=%{x}\u003cbr\u003e#Delinquent customers=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2s}","x":["Declined","White","Not Set","Asian","Other Race","Black or African American"],"xaxis":"x","y":[87,76,75,28,8,7],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"} ...

# %%
# Check the ethnicity distribution of the delinquent for 60 days customers
delinquent_60_ethnicity = delinquent_60_demograph['Ethnicity'].value_counts()

#Create a bar plot
fig = px.bar(x=delinquent_60_ethnicity.index, y=delinquent_60_ethnicity.values, title='Ethnicity distribution of deliquent for 60 days ', labels={'x': 'ethnicity', 'y': '#Delinquent customers'},  text_auto='.2s')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6da82c94-fdee-4675-ad36-bbb5cdb550b9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6da82c94-fdee-4675-ad36-bbb5cdb550b9")) {                    Plotly.newPlot(                        "6da82c94-fdee-4675-ad36-bbb5cdb550b9",                        [{"alignmentgroup":"True","hovertemplate":"ethnicity=%{x}\u003cbr\u003e#Delinquent customers=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2s}","x":["Not Hispanic or Latino","Declined","Not Set","Hispanic or Latino"],"xaxis":"x","y":[104,85,75,17],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scatte ...
